# %%
import numpy as np
#random missing and soft impute
soft1=np.array([ 22,39,43,97,110,81,92,116,120])
soft2=np.array([ 39,97,110,81,92,112,116,120.])
soft3=np.array([ 39,49,97,110,81,83,92,116,120])
soft4=np.array([ 19,39,97,110,81,92,93,116,120])
soft5=np.array([ 39,49,97,110,81,92,116,120])
soft6=np.array([ 22,39,49,97,110,81,92,116,120])
soft7=np.array([ 39,97,110,81,92,116,120])
soft8=np.array([ 39,97,110,81,92,116,120])
soft9=np.array([  0,39,97,110,81,92,116,120])
soft10=np.array([ 39,43,97,110,81,92,116,120])
score=np.array([0.28863611,0.27516068,0.26625792,0.28166749,0.28822205,0.29232699,0.28869516,0.28115911,0.28970304,0.2863328])
set(soft1)&set(soft2)&set(soft3)&set(soft4)&set(soft5)&set(soft6)&set(soft7)&set(soft8)&set(soft9)&set(soft10)
# Out:
# {39, 81, 92, 97, 110, 116, 120}

# %%
#mbf soft

softM1=np.array([14,31,33,49,68,73,97,110,81,92,116,120,134])
softM2=np.array([4,6,7,11,19,39,52,67,70,110,81,92,120,134,135,140])
softM3=np.array([21,22,33,39,49,67,102,110,81,92,116,120])
softM4=np.array([22,25,43,49,61,70,89,96,97,101,110,81,92,116,120,142])
softM5=np.array([1,5,9,22,110,79,81,92,105,116,120,130])
softM6=np.array([3,5,6,7,8,19,39,47,49,89,97,110,81,92,113,116,120,134])
softM7=np.array([2,4,5,6,7,9,39,43,53,97,110,81,92,116,120,130])
softM8=np.array([7,8,22,49,97,110,81,92,116,118,120,134])
softM9=np.array([21,31,39,49,70,82,90,97,110,127,81,83,92,120])
softM10=np.array([7,33,97,110,72,81,92,106,107,116,120])

scoreM=np.array([0.26246809,0.26508272,0.28350317,0.280454,0.27696664,0.27169784,0.2715403,0.279255,0.25618075,0.25394389])

set(softM1)&set(softM2)&set(softM3)&set(softM4)&set(softM5)&set(softM6)&set(softM7)&set(softM8)&set(softM9)&set(softM10)
# Out:
# {81, 92, 110, 120}

# %%
# random missing and mean impute
mean1=np.array([ 39,  43,  49,  70,  97, 110,  81,  92, 116, 120, 130])
mean2=np.array([ 19,  39,  43,  49,  97, 110,  81,  92, 116, 120])
mean3=np.array([ 19,  39,  49,  97, 110,  81,  92, 116, 120])
mean4=np.array([ 19,  39,  49,  97, 110,  81,  92, 106, 116, 120, 134])
mean5=np.array([ 39,  49,  97, 110,  81,  84,  92, 116, 120])
mean6=np.array([ 39,  49,  97, 110,  81,  92, 116, 120, 131])
mean7=np.array([ 39,  43,  49,  97, 110,  81,  92, 116, 120])
mean8=np.array([ 39,  49,  97, 110,  81,  92, 116, 120, 130])
mean9=np.array([ 39,  43,  49,  97, 110,  81,  92, 116, 120])
mean10=np.array([ 39,  97, 110,  81,  92, 116, 120])

meanScore=np.array([0.30221332,0.29390071,0.28487832,0.28605767,0.29204145,0.29054609,0.28945875,0.30015482,0.29657769,0.29846784])
set(mean1)&set(mean2)&set(mean3)&set(mean4)&set(mean5)&set(mean6)&set(mean7)&set(mean8)&set(mean9)&set(mean10)
# Out:
# {39, 81, 92, 97, 110, 116, 120}

# %%
# mbf mean impute
meanM1=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM2=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM3=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM4=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM5=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM6=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM7=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM8=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM9=np.array([ 39,  97, 110,  81,  92, 116, 120])
meanM10=np.array([ 39,  97, 110,  81,  92, 116, 120])


meanMscore=np.array([0.27584298,0.28398105,0.28944321,0.28404941,0.27537315,0.2787337,0.28339885,0.28706989,0.28912546,0.2873552])
set(meanM1)&set(meanM2)&set(meanM3)&set(meanM4)&set(meanM5)&set(meanM6)&set(meanM7)&set(meanM8)&set(meanM9)&set(meanM10)
# Out:
# {39, 81, 92, 97, 110, 116, 120}

# %%
print(np.mean(score))
print(np.mean(scoreM))
print(np.mean(meanScore))
print(np.mean(meanMscore))
# Out:
# 0.28381613499999997
# 0.27010924
# 0.293429666
# 0.28343729
