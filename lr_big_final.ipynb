# %%
#random missing soft impute
import numpy as np
soft1=np.array([ 54,  89, 101, 108, 112, 115, 119, 131, 151, 153, 155,  40,  52,  67,81,  90, 112])
soft2=np.array([ 26,  54,  87,  89, 101, 112, 113, 115, 131, 151, 168,  62,  67,  73,81,  90,  96,  97, 112, 113, 122])
soft3=np.array([ 89, 101, 112, 115, 124, 151, 155, 167,  52,  67,  73,  81,  90,  97, 113])
soft4=np.array([ 26,  54,  87,  89, 101, 112, 115, 119, 124, 161,  40,  52,  62,  81, 96,  97, 122, 131])
soft5=np.array([ 89, 101, 112, 113, 119, 124, 151,  62,  67,  79,  81,  90,  97,99,113])
soft6=np.array([ 26,  52,  57,  87,  89, 101, 112, 115, 132, 151, 155,  52,  67,  81,90,  97, 104, 112])
soft7=np.array([ 26,  57,  87, 101, 112, 115, 119, 132, 151, 153,  40,  52,  62,  67, 69,  81,  90,  97, 122, 131])
soft8=np.array([ 54,  89, 101, 112, 119, 124, 133, 136, 151, 155, 161,  40,  52,  62,67,  73,  81,  90,  97, 113])
soft9=np.array([ 26,  87,  89, 112, 115, 132, 151,  40,  47,  52,  62,  65,  67,  73,81,  96,  97, 131])
soft10=np.array([ 24,  87, 101, 112, 113, 115, 119, 126, 151,  52,  62,  67,  90,  96,  97, 104, 113, 131])
total=np.array([soft1,soft2,soft3,soft4,soft5,soft6,soft7,soft8,soft9,soft10])
score=np.array([0.31609544,0.31536497,0.31670389,0.31671139,0.31600721,0.31639004,0.31739284,0.31630888,0.31695279,0.31571944])
set(soft1)&set(soft2)&set(soft3)&set(soft4)&set(soft5)&set(soft6)&set(soft7)&set(soft8)&set(soft9)&set(soft10)
# Out:
# /Users/wenjinyuan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   del sys.path[0]
# {112}

# %%
softM1=np.array([ 26,  54,  87, 112, 115, 153, 167,  40,  62,  67,  79,  90, 104])
softM2=np.array([ 54, 113, 119, 124,  47,  62,  67,  79,  81,  90])
softM3=np.array([ 54,  57,  89, 101, 112, 115, 155, 169,  62,  96, 113, 122])
softM4=np.array([101, 112, 115, 119, 124, 131, 151, 153,  40,  67,  73,  81, 112])
softM5=np.array([ 34, 101, 131, 155,  40,  54,  62,  67,  81,  96,  97, 131])
softM6=np.array([ 54, 113, 124, 136, 151,  52,  62,  67,  81,  86,  90])
softM7=np.array([ 54,  57,  89,  98, 101, 112, 119, 132, 151,  52,  81,  90,  97, 113,131])
softM8=np.array([ 26,  52,  54,  89, 101, 119, 124, 148,  79,  81,  90,  97, 112, 122])
softM9=np.array([ 52,  54,  57, 101, 108, 112, 119, 151,  62,  67,  96,  97])
softM10=np.array([ 26,  87, 119, 155,  54,  67,  97, 113, 129])

scoreM=np.array([0.31185328,0.3124782,0.31131603,0.3152979,0.30892148,0.31011174,0.31495455,0.31409761,0.31068339,0.31334926])
set(softM1)&set(softM2)&set(softM3)&set(softM4)&set(softM5)&set(softM6)&set(softM7)&set(softM8)&set(softM9)&set(softM10)
# Out:
# set()

# %%
#random missing meam impute

mean1=np.array([ 24,  59, 101, 136,  54,  57,  62,  67,  90,  97, 100, 131])
mean2=np.array([ 47,  52, 124, 126, 136,  40,  67,  90, 113, 122])
mean3=np.array([111, 112,  40,  62,  67, 113])
mean4=np.array([ 57,  91, 112, 119, 129, 136,  40,  57,  62,  90, 113])
mean5=np.array([ 26,  30,  52,  54,  57,  59,  89, 151,  67,  81,  97, 131])
mean6=np.array([126, 136, 143, 155,  40, 112])
mean7=np.array([ 72, 101, 136,  52,  54,  67,  90,  97, 112])
mean8=np.array([ 26,  52,  91, 115, 124, 151,  54,  81,  86, 114, 129])
mean9=np.array([ 40,  72,  91, 124, 161,  47,  65,  67,  81,  90, 131])
mean10=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanScore=np.array([-0.92455693,-0.94097812,-0.98028143,-0.93147721,-0.92866446,-0.93930999,-0.87320616,-0.91487438,-0.90202767,-0.84803664])
set(mean1)&set(mean2)&set(mean3)&set(mean4)&set(mean5)&set(mean6)&set(mean7)&set(mean8)&set(mean9)&set(mean10)
# Out:
# set()

# %%
meanM1=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM2=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM3=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM4=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM5=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM6=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM7=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM8=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM9=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])
meanM10=np.array([101, 112, 136, 151,  47,  52,  65,  67,  90,  97])

meanMscore=np.array([ 0.17968581,0.08227616,0.09648213 ,0.16452436, 0.29294119 ,0.09028483,0.22162916 ,0.17156588,-0.01895995 ,0.26526203])
set(meanM1)&set(meanM2)&set(meanM3)&set(meanM4)&set(meanM5)&set(meanM6)&set(meanM7)&set(meanM8)&set(meanM9)&set(meanM10)
# Out:
# {47, 52, 65, 67, 90, 97, 101, 112, 136, 151}

# %%
print(np.mean(score))
print(np.mean(scoreM))
print(np.mean(meanScore))
print(np.mean(meanMscore))
# Out:
# 0.31636468900000003
# 0.31230634399999996
# -0.918341299
# 0.15456916
